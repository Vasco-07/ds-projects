# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasco-07/ds-projects/blob/main/1B-program-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
dummy_data = [
    {"id": 1, "name": "Alice", "age": 20, "major": "Computer Science"},
    {"id": 2, "name": "Bob", "age": 22, "major": "Physics"},
    {"id": 3, "name": "Charlie", "age": 21, "major": "Mathematics"}
]

with open("/tmp/students.json", "w") as f:
    json.dump(dummy_data, f)

df = pd.read_json("/tmp/students.json")

print("Student Data")
print(df)
# Out:
# Student Data
#    id     name  age             major
# 0   1    Alice   20  Computer Science
# 1   2      Bob   22           Physics
# 2   3  Charlie   21       Mathematics
