# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasco-07/ds-projects/blob/main/4-exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = pd.Series(
    np.random.randn(6),
    index=[
        ['a', 'a', 'b', 'b', 'c', 'c'],
        [1, 2, 1, 2, 1, 2]
    ]
)
print(data)
print(data['b'])
print(data[:, 1])
# Out:
# a  1   -0.279276
#    2    0.061789
# b  1    0.784995
#    2    1.472281
# c  1    0.652380
#    2    0.111343
# dtype: float64
# 1    0.784995
# 2    1.472281
# dtype: float64
# a   -0.279276
# b    0.784995
# c    0.652380
# dtype: float64

# %%
import pandas as pd
import numpy as np
data = pd.Series(
    np.random.randn(6),
    index=[
        ['a', 'a', 'b', 'b', 'c', 'c'],
        [1, 2, 1, 2, 1, 2]
    ]
)
df = data.unstack()
print(df)
print(df.stack())
# Out:
#           1         2
# a  1.037301  0.418998
# b -0.558861  0.495618
# c  0.670977  0.393780
# a  1    1.037301
#    2    0.418998
# b  1   -0.558861
#    2    0.495618
# c  1    0.670977
#    2    0.393780
# dtype: float64

# %%
import pandas as pd
import numpy as np
df1 = pd.DataFrame({
    'a': [1, np.nan, 3],
    'b': [4, 5, 6]
})
df2 = pd.DataFrame({
    'a': [7, 8, 9],
    'b': [np.nan, 11, 12]
})
merged = df1.combine_first(df2)
print(merged)
# Out:
#      a    b
# 0  1.0  4.0
# 1  8.0  5.0
# 2  3.0  6.0
