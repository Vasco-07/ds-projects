# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasco-07/ds-projects/blob/main/1B-program-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from io import StringIO

json_data = """
[
    {
        "Roll_No": 101,
        "Name": "Anusha",
        "Marks": 89
    },
    {
        "Roll_No": 102,
        "Name": "Babitha",
        "Marks": 92
    },
    {
        "Roll_No": 103,
        "Name": "Charitha",
        "Marks": 88
    }
]
"""

df = pd.read_json(StringIO(json_data))

print("Parsed JSON Data")
print(df)
# Out:
# Parsed JSON Data
#    Roll_No      Name  Marks
# 0      101    Anusha     89
# 1      102   Babitha     92
# 2      103  Charitha     88
